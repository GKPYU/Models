# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt


  
# Opening JSON file
f = open('2022_11_22-162227_preds.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
label=[]
y_pred_proba=[]
# Iterating through the json
# list
for i in range(len(data)):
    value=data[i]['val']
    predict=data[i]['pred']
    
    z = 1/(1 + np.exp(-predict))
   
    
    
    label.append(value)
    y_pred_proba.append(predict)
    
  
# Closing file
f.close()
fpr, tpr, _ = metrics.roc_curve(label,  y_pred_proba)
auc = metrics.roc_auc_score(label, y_pred_proba)
fpr, tpr, thresholds = metrics.roc_curve(label,y_pred_proba)
#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.plot( [0, 1], [0, 1])

plt.legend(loc=4)

plt.show()

z = 1/(1 + np.exp(-thresholds))
print(z[10])

fpr[10]
# Out:
# 0.7584693381520378
# 0.0003484320557491289

# %%
print(data[1]['pred'])
# Out:
# 0.00994130875915289

# %%
len(data)
# Out:
# 7392
